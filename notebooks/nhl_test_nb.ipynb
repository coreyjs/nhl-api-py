# %%
#!pip install -i https://test.pypi.org/simple/ nhl-api-py -U --no-cache-dir
# !pip install websockets

! pip install  nhl-api-py -U --no-cache-dir

# %%
import logging

logging.basicConfig(
                    level=logging.DEBUG,
                    force=True, # Resets any previous configuration
                    )

# %%
from nhlpy.api.query.builder import QueryBuilder, QueryContext
from nhlpy.nhl_client import NHLClient
from nhlpy.api.query.filters.draft import DraftQuery
from nhlpy.api.query.filters.season import SeasonQuery
from nhlpy.api.query.filters.game_type import GameTypeQuery
from nhlpy.api.query.filters.position import PositionQuery, PositionTypes

client = NHLClient(debug=True)

filters = [
    GameTypeQuery(game_type="2"),
    DraftQuery(year="2020", draft_round="2"),
    SeasonQuery(season_start="20202021", season_end="20232024"),
    PositionQuery(position=PositionTypes.ALL_FORWARDS)
]

query_builder = QueryBuilder()
query_context: QueryContext = query_builder.build(filters=filters)

data = client.stats.skater_stats_with_query_context(
    report_type='summary',
    query_context=query_context,
    aggregate=True
)
data
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a62ba819c10>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2210> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d389fd0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.stats.gametypes_per_season_directory_by_team(team_abbr="TOR") # kinda weird endpoint.
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d344a90>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629cb0ade0> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d3c5490>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.stats.player_career_stats(player_id="8478402")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d3472d0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2600> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d3456d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.stats.player_game_log(player_id="8478402", season_id="20242025", game_type="2")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d345b90>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b23c0> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d345bd0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.stats.team_summary(start_season="20202021", end_season="20212022", game_type_id=2)
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d7df810>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2690> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d342210>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.stats.team_summary(start_season="20202021", end_season="20212022")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d31ddd0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d7a2de0> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd4d590>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.stats.skater_stats_summary(start_season="20232024", end_season="20232024")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d7df810>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2d50> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d7da150>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.stats.skater_stats_summary(franchise_id=10, start_season="20232024", end_season="20232024")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d346dd0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2450> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd38510>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.stats.goalie_stats_summary(start_season="20242025", stats_type="summary")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d389ed0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629c651250> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd3a1d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.schedule.daily_schedule(date="2025-01-11")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d31cf90>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2210> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd33c50>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.schedule.weekly_schedule(date="2021-01-13")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a62b9f1c210>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2450> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd977d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.schedule.team_monthly_schedule(team_abbr="BUF")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd2f8d0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b3410> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd974d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.schedule.team_monthly_schedule(team_abbr="BUF", month="2021-01")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cb50ed0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2690> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd98450>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.schedule.team_weekly_schedule(team_abbr="BUF")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cde8610>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629c651250> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd981d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.schedule.team_weekly_schedule(team_abbr="BUF", date="2024-01-01")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd99010>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b3f50> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd94310>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.schedule.team_season_schedule(team_abbr="BUF", season="20212022")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cdf2690>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2960> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cb3ad10>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.schedule.calendar_schedule(date="2023-11-23")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cd94110>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629c651250> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cde04d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.standings.league_standings()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf69910>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b3770> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629d35e350>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.standings.league_standings(date="2021-01-13")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cdc8d50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629cf4d520> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf18990>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.standings.league_standings(season="20222023")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf19710>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b3da0> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf18b10>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.standings.season_standing_manifest()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf5e910>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b2450> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf5ef50>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.teams.teams()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cdf2390>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629cf4db50> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf1a690>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.teams.team_roster(team_abbr="BUF", season="20232024")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628e015a50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d9328d0> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628ddb9a50>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.teams.franchises()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628e1d6e50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b3da0> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628d9a3ad0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.game_center.boxscore(game_id="2023020280")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf42390>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b3890> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628d9d9990>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.game_center.play_by_play(game_id="2023020280")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628d9a2850>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d932c30> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628d9daf90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.game_center.match_up(game_id="2023020280")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628d9a3990>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b3f50> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a629cf66b90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.game_center.daily_scores()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628df55b10>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d9329f0> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628d7278d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.game_center.shift_chart_data(game_id="2024030416")
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628d9bb590>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a629d3b3f50> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a628d867710>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.game_center.season_series_matchup(game_id='2024030416')
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d1250d0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d8a8290> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d00fa90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.game_center.game_story(game_id='2024030416')
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d026390>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d8a8050> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d02e2d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.misc.glossary()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d35c8d0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d933da0> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d00e0d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.misc.config()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d02ec10>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d8a8050> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d02f5d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.misc.countries()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d076990>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a627cfad880> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627cffbb90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.misc.season_specific_rules_and_info()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d1b5cd0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a627cfaf020> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d026590>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.misc.draft_year_and_rounds()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d0262d0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d932d50> server_hostname='api.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d026650>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.game_center.season_series_matchup(game_id='2023020280')
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d6f6a10>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a628d8a8290> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d018510>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
#2024020895

plays = client.game_center.play_by_play(game_id="2024020895")

sch = client.schedule.daily_schedule("2025-03-19") #2024021087
sch
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d027210>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a627cf451c0> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627e159490>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...

# %%
client.teams.teams()
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='api-web.nhle.com' port=443 local_address=None timeout=10 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627d018510>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7a627cf452e0> server_hostname='api-web.nhle.com' timeout=10
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7a627cdc25d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...
